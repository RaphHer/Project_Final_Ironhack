# %% [markdown]
# ## 7. Monte Carlo Analysis

# %%
# retrived from https://medium.com/the-handbook-of-coding-in-finance/simulating-random-walk-of-stock-prices-with-monte-carlo-simulation-in-python-6e233d841e

# %% [markdown]
# A Monte Carlo simulation is a model used to predict the probability of different outcomes when the intervention of random variables is present. A Monte Carlo simulation is used to tackle a range of problems in many fields including investing, business, physics, and engineering. It is also referred to as a multiple probability simulation.
#
# [Investopedia](https://www.investopedia.com/terms/m/montecarlosimulation.asp)

# %%
import yfinance as yf #Yahoo Finance 
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')gs
# Out:
#   Input In [15]
#     warnings.filterwarnings('ignore')gs
#                                      ^
# SyntaxError: invalid syntax

# %%
start = dt.datetime(2011, 1, 1)
end = dt.datetime(2022, 11, 29)
stock_data = yf.download('^GSPC', start, end) #GSPC is the ticker for the S&P 500
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2011-01-03  1257.619995  1276.170044  1257.619995  1271.869995  1271.869995
# 2011-01-04  1272.949951  1274.119995  1262.660034  1270.199951  1270.199951
# 2011-01-05  1268.780029  1277.630005  1265.359985  1276.560059  1276.560059
# 2011-01-06  1276.290039  1278.170044  1270.430054  1273.849976  1273.849976
# 2011-01-07  1274.410034  1276.829956  1261.699951  1271.500000  1271.500000
# ...                 ...          ...          ...          ...          ...
# 2022-11-21  3956.229980  3962.000000  3933.340088  3949.939941  3949.939941
# 2022-11-22  3965.510010  4005.879883  3956.879883  4003.580078  4003.580078
# 2022-11-23  4000.300049  4033.780029  3998.659912  4027.260010  4027.260010
# 2022-11-25  4023.340088  4034.020020  4020.760010  4026.120117  4026.120117
# 2022-11-28  4005.360107  4012.270020  3955.770020  3963.939941  3963.939941
#
#                 Volume
# Date
# ...

# %%
returns = stock_data['Adj Close'].pct_change()
daily_vol = returns.std()

# %%
daily_vol
# Out:
# 0.01119790507582475

# %%
T = 252
count = 0
price_list = []
last_price = stock_data['Adj Close'][-1]

price = last_price * (1 + np.random.normal(0, daily_vol))
price_list.append(price)

for y in range(T):
    if count == 251:
        break
    price = price_list[count]* (1 + np.random.normal(0, daily_vol))
    price_list.append(price)
    count += 1

plt.plot(price_list)
plt.show()

# %%
NUM_SIMULATIONS =  10000
df = pd.DataFrame()
last_price_list = []
for x in range(NUM_SIMULATIONS):
    count = 0
    price_list = []
    price = last_price * (1 + np.random.normal(0, daily_vol))
    price_list.append(price)
    
    for y in range(T):
        if count == 251:
            break
        price = price_list[count]* (1 + np.random.normal(0, daily_vol))
        price_list.append(price)
        count += 1
        
    df[x] = price_list
    last_price_list.append(price_list[-1])
        
fig = plt.figure()
fig.suptitle("Monte Carlo Simulation: S&P 500")
plt.plot(df)
plt.xlabel('Day')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13464\268462863.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[x] = price_list
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13464\268462863.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[x] = price_list
# ...

# %%
print("Expected price: ", round(np.mean(last_price_list),2))
print("Quantile (5%): ",np.percentile(last_price_list,5))
print("Quantile (95%): ",np.percentile(last_price_list,95))
# Out:
# Expected price:  3959.71
# Quantile (5%):  2898.389767489332
# Quantile (95%):  5218.351701501956

# %%
plt.hist(last_price_list,bins=100)
plt.title('Monte Carlo Distribution')
plt.axvline(np.percentile(last_price_list,5), color='r', linestyle='dashed', linewidth=2)
plt.axvline(np.percentile(last_price_list,95), color='r', linestyle='dashed', linewidth=2)
plt.show()
