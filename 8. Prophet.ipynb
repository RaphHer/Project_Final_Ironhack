# %% [markdown]
# # 8. Prophet

# %%
import matplotlib.pyplot as plt
import yfinance as yf 
from prophet import Prophet

# %% [markdown]
# Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well. Prophet is open source software released by Facebook’s Core Data Science team. It is available for download on CRAN and PyPI [Facebook](https://facebook.github.io/prophet/#:~:text=Prophet%20is%20a%20forecasting%20procedure,Install%20Prophet).

# %%
 def prophet_pred (ticker, date):
        df = yf.download(ticker, start=date)
        df = df.reset_index()
        df [['ds','y']] = df[['Date','Adj Close']]
        return df

# %% [markdown]
# ### Prophet Projection S&P 500 with data starting in 1945

# %%
df_sp500 = prophet_pred ('^GSPC', '1945-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
model = Prophet()
model.fit(df_sp500) # no needs to specify which column to take as it will take by default the ds and y column
# Out:
# 15:43:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:43:57 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(5*365)
forecast = model.predict(future)
forecast
# Out:
#               ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0     1945-01-02     9.196205  -219.605948   258.084409     9.196205
# 1     1945-01-03     9.202451  -220.445141   262.404136     9.202451
# 2     1945-01-04     9.208698  -238.310418   258.741172     9.208698
# 3     1945-01-05     9.214944  -214.409714   249.295492     9.214944
# 4     1945-01-08     9.233683  -219.071910   268.018405     9.233683
# ...          ...          ...          ...          ...          ...
# 21414 2027-11-24  4700.040239  4272.038421  5113.714895  4335.509938
# 21415 2027-11-25  4700.571349  4261.766326  5132.456534  4335.593267
# 21416 2027-11-26  4701.102459  4285.931686  5139.283699  4335.676597
# 21417 2027-11-27  4701.633570  4297.869267  5123.495431  4335.759927
# 21418 2027-11-28  4702.164680  4286.644226  5103.392333  4335.843256
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 0         9.196205        5.404492              5.404492
# ...

# %%
model.plot(forecast)
plt.show()
plt.title('Prophet ')

# %%
model.plot_components(forecast)
plt.show()

# %% [markdown]
# ### Prophet Projection S&P 500 with data starting in 1980

# %%
df_sp500 = prophet_pred ('^GSPC', '1980-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
model = Prophet()
model.fit(df_sp500) # no needs to specify which column to take as it will take by default the ds and y column
# Out:
# 15:51:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:51:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(5*365)
forecast = model.predict(future)
forecast
# Out:
#               ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0     1980-01-02   105.448056   -49.435298   319.735891   105.448056
# 1     1980-01-03   105.480713   -55.342607   308.249553   105.480713
# 2     1980-01-04   105.513370   -75.596488   304.188410   105.513370
# 3     1980-01-07   105.611340   -64.307795   320.252104   105.611340
# 4     1980-01-08   105.643997   -38.990490   310.168899   105.643997
# ...          ...          ...          ...          ...          ...
# 12641 2027-11-24  5670.732768  4924.740366  6423.140866  4951.511010
# 12642 2027-11-25  5671.547708  4927.369393  6419.565743  4951.616944
# 12643 2027-11-26  5672.362649  4951.514447  6401.530225  4951.722879
# 12644 2027-11-27  5673.177589  4928.900519  6432.088312  4951.828814
# 12645 2027-11-28  5673.992529  4938.544902  6447.029213  4951.934748
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 0       105.448056       18.223851             18.223851
# ...

# %%
model.plot(forecast)
plt.show()

# %%
model.plot_components(forecast)
plt.show()

# %% [markdown]
# ### Prophet Projection S&P 500 with data starting in 2000

# %%
df_sp500 = prophet_pred ('^GSPC', '2000-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
model = Prophet()
model.fit(df_sp500) # no needs to specify which column to take as it will take by default the ds and y column
# Out:
# 15:55:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:55:51 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(5*365)
forecast = model.predict(future)
forecast
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    2000-01-03  1485.091739  1313.287434  1734.420129  1485.091739
# 1    2000-01-04  1484.657427  1320.425705  1733.566426  1484.657427
# 2    2000-01-05  1484.223115  1312.257676  1728.347481  1484.223115
# 3    2000-01-06  1483.788802  1321.514805  1745.097438  1483.788802
# 4    2000-01-07  1483.354490  1317.041624  1741.002265  1483.354490
# ...         ...          ...          ...          ...          ...
# 7585 2027-11-24  6496.558277  5462.505886  7704.804698  5503.617134
# 7586 2027-11-25  6497.684052  5471.349689  7722.494553  5503.791869
# 7587 2027-11-26  6498.809828  5502.538495  7687.150063  5503.966604
# 7588 2027-11-27  6499.935603  5453.408461  7721.016292  5504.141339
# 7589 2027-11-28  6501.061379  5465.029231  7749.363461  5504.316074
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
 = df_sp500[7589] / df_sp[]

# %%
model.plot(forecast)
plt.show()

# %% [markdown]
# ### Prophet Projection S&P 500 with data starting in 2019

# %%
df_sp500 = prophet_pred ('^GSPC', '2019-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
model = Prophet()
model.fit(df_sp500) # no needs to specify which column to take as it will take by default the ds and y column
# Out:
# 15:57:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(5*365)
forecast = model.predict(future)
forecast
# Out:
#              ds        trend    yhat_lower    yhat_upper   trend_lower  \
# 0    2019-01-02  2453.008780   2496.904577   2753.356691   2453.008780
# 1    2019-01-03  2457.680703   2498.523165   2752.772634   2457.680703
# 2    2019-01-04  2462.352626   2497.569556   2769.832358   2462.352626
# 3    2019-01-07  2476.368397   2518.941429   2775.561131   2476.368397
# 4    2019-01-08  2481.040320   2522.150375   2769.096081   2481.040320
# ...         ...          ...           ...           ...           ...
# 2806 2027-11-24  -182.676403 -12373.394773  11102.230548 -12468.617021
# 2807 2027-11-25  -184.853269 -12348.774438  11170.409331 -12480.939804
# 2808 2027-11-26  -187.030134 -12405.514751  11176.088263 -12493.262588
# 2809 2027-11-27  -189.206999 -12457.801835  11229.077375 -12505.585372
# 2810 2027-11-28  -191.383864 -12401.367802  11074.049584 -12517.908156
#
#        trend_upper  additive_terms  additive_terms_lower  \
# ...

# %%
model.plot(forecast)
plt.show()

# %% [markdown]
# ### Prophet Projection S&P 500 with data starting in 2019 and shortening to 1 year

# %%
df_sp500 = prophet_pred ('^GSPC', '2022-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
model = Prophet()
model.fit(df_sp500) # no needs to specify which column to take as it will take by default the ds and y column
# Out:
# 15:58:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:51 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(365)
forecast = model.predict(future)
forecast
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   2022-01-03  4643.832790  4464.443315  4775.567670  4643.832790
# 1   2022-01-04  4640.120528  4464.958012  4776.373289  4640.120528
# 2   2022-01-05  4636.408267  4460.705579  4773.572855  4636.408267
# 3   2022-01-06  4632.696006  4444.747795  4765.849082  4632.696006
# 4   2022-01-07  4628.983744  4424.598284  4747.261782  4628.983744
# ..         ...          ...          ...          ...          ...
# 589 2023-11-25  4256.606636  1338.443565  7152.567815  1268.428344
# 590 2023-11-26  4257.607121  1326.112812  7216.834354  1253.597259
# 591 2023-11-27  4258.607605  1227.029497  7082.555066  1239.133046
# 592 2023-11-28  4259.608089  1159.204633  7123.901616  1224.668833
# 593 2023-11-29  4260.608573  1239.659892  7075.185402  1210.204790
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    4643.832790      -23.418184            -23.418184            -23.418184
# ...

# %%
model.plot(forecast)
plt.show()
